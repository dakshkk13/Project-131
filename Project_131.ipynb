# %% [markdown]
# <a href="https://colab.research.google.com/github/dakshkk13/Project-131/blob/main/Project_131.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/procodingclass/PRO-Stars-Dataset-CSVs
# Out:
# Cloning into 'PRO-Stars-Dataset-CSVs'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 26 (delta 10), reused 12 (delta 5), pack-reused 0
# Receiving objects: 100% (26/26), 27.77 KiB | 1.46 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
import pandas as pd
df = pd.read_csv("/content/PRO-Stars-Dataset-CSVs/final_data.csv")
df.head()
# Out:
#    Unnamed: 0       Star_name     Distance  Mass Radius
# 0           0             Sun  0.000015813   1.0      1
# 1           1          Sirius          8.6   2.1   1.71
# 2           2         Canopus          310  15.0     71
# 3           3  Alpha Centauri          4.4   1.1    1.2
# 4           4        Arcturus           37   1.1     26

# %%
df.drop(['Unnamed: 0'],axis = 1, inplace = True)
df.head()
# Out:
#         Star_name     Distance  Mass Radius
# 0             Sun  0.000015813   1.0      1
# 1          Sirius          8.6   2.1   1.71
# 2         Canopus          310  15.0     71
# 3  Alpha Centauri          4.4   1.1    1.2
# 4        Arcturus           37   1.1     26

# %%
df.dtypes
# Out:
# Star_name     object
# Distance      object
# Mass         float64
# Radius        object
# dtype: object

# %%
df['Radius']=df['Radius'].apply(lambda x: x.replace('$', '').replace(',', '')).astype('float')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-9b653c26b4c5> in <cell line: 1>()
# ----> 1 df['Radius']=df['Radius'].apply(lambda x: x.replace('$', '').replace(',', '')).astype('float')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4769         dtype: float64
#    4770         """
# -> 4771         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4772
#    4773     def _reduce(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1121
#    1122         # self.f is Callable
# -> 1123         return self.apply_standard()
#    1124
#    1125     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1172             else:
# ...

# %%
radius = df['Radius'].to_list()
mass = df['Mass'].to_list()
gravity = []
def convert_to_SI(radius,mass):
  for i in range (0,len(radius)-1):
    radius[i] = radius[i]*6.957e+8
    mass[i] = mass[i]*1.989e+30
convert_to_SI(radius,mass)

# %%
def gravity_calculations(radius,mass):
  G = 6.674e-11
  for index in range(0,len(mass)):
    g= (mass[index]*G)/((radius[index])**2)
    gravity.append(g)
gravity_calculations(radius,mass)
df["Gravity"] = gravity
df
# Out:
#                   Star_name     Distance       Mass     Radius       Gravity
# 0                       Sun  0.000015813   1.000000   1.000000  2.742692e+02
# 1                    Sirius          8.6   2.100000   1.710000  1.969718e+02
# 2                   Canopus          310  15.000000  71.000000  8.161153e-01
# 3            Alpha Centauri          4.4   1.100000   1.200000  2.095112e+02
# 4                  Arcturus           37   1.100000  26.000000  4.462960e-01
# ..                      ...          ...        ...        ...           ...
# 248  2MASSI J2356547-155310           74   0.076367   0.112012  1.669385e+03
# 249          WISE 0410+1502           20   0.005728   0.120233  1.086673e+02
# 250         WISE 0458+6434A         35.9   0.014319   0.431605  2.108201e+01
# 251         WISE 0458+6434B         35.9   0.009546   0.390499  1.716928e+01
# 252          WISE 1405+5534         25.3   0.028638   0.088376  2.447107e-10
#
# [253 rows x 5 columns]

# %%
df.dtypes
# Out:
# Star_name     object
# Distance      object
# Mass         float64
# Radius       float64
# Gravity      float64
# dtype: object

# %%
df.to_csv("star_with_gravity.csv")
